# %%
import pandas as pd

# %%
annual_financial_data = pd.read_excel("Annual Financial Data (Merged).xlsx")
quarterly_financial_data = pd.read_excel("Quarterly Financial Data (Merged).xlsx")

# %%
annual_financial_data_column_list = list(annual_financial_data.columns)
quarterly_financial_data_column_list = list(quarterly_financial_data.columns)

# %%
similar_columns = []
quarterly_columns_not_in_annual = []

for quarterly_column in quarterly_financial_data_column_list:
    if quarterly_column in annual_financial_data:
        similar_columns.append(quarterly_column)
    if quarterly_column not in annual_financial_data_column_list:
        quarterly_columns_not_in_annual.append(quarterly_column)


annual_columns_not_in_quarterly = []

for annual_column in annual_financial_data_column_list:
    if annual_column not in quarterly_financial_data_column_list:
        annual_columns_not_in_quarterly.append(annual_column)

# %%
quarterly_columns_drop = ['Non-Current Assets - Total',
                          'Total Shares Repurchased - Quarter',
                          'Pension Core Adjustment - 12mm',
                          'Earnings Per Share (Diluted) - Including Extraordinary Items.1',
                          'Earnings Per Share (Basic) - Including Extraordinary Items - 12 Months Moving',
                          'Earnings Per Share - Diluted - from Operations - 12MM',
                          'Earnings Per Share from Operations - 12 Months Moving',
                          'Gain/Loss on Sale (Core Earnings Adjusted) After-tax 12MM',
                          'Gain/Loss on Sale (Core Earnings Adjusted) Diluted EPS Effect 12MM',
                          'Gain/Loss on Sale (Core Earnings Adjusted) Basic EPS Effect 12MM',
                          'Income Before Extra Items - Adj for Common Stock Equivalents - 12MM',
                          'Interest Accrued',
                          'Inventory - Work in Process',
                          'Total Long-term Investments',
                          'Long-Term Liabilities (Total)',
                          'Liabilities - Total and Noncontrolling Interest',
                          'Noncontrolling Interest - Redeemable - Balance Sheet',
                          'Repurchase Price - Average per share Quarter',
                          'Receivables - Current Other incl Tax Refunds',
                          'Core Pension Adjustment Diluted EPS Effect 12MM',
                          'Core Pension Adjustment Basic EPS Effect 12MM',
                          'Core Pension Interest Adjustment After-tax Preliminary',
                          'Core Pension Interest Adjustment Diluted EPS Effect Preliminary',
                          'Core Pension Interest Adjustment Basic EPS Effect Preliminary',
                          'Core Pension Interest Adjustment Pretax Preliminary',
                          'Core Pension Adjustment 12MM Diluted EPS Effect Preliminary',
                          'Core Pension Adjustment Diluted EPS Effect Preliminary',
                          'Core Pension Adjustment 12MM Basic EPS Effect Preliminary',
                          'Core Pension Adjustment Basic EPS Effect Preliminary',
                          'Core Pension Adjustment Preliminary',
                          'Core Pension w/o Interest Adjustment After-tax Preliminary',
                          'Core Pension w/o Interest Adjustment Diluted EPS Effect Preliminary',
                          'Core Pension w/o Interest Adjustment Basic EPS Effect Preliminary',
                          'Core Pension w/o Interest Adjustment Pretax Preliminary',
                          'Core Post Retirement Adjustment Diluted EPS Effect 12MM',
                          'Core Post Retirement Adjustment 12MM',
                          'Core Post Retirement Adjustment Basic EPS Effect 12MM',
                          'Core Post Retirement Adjustment 12MM Diluted EPS Effect Preliminary',
                          'Core Post Retirement Adjustment Diluted EPS Effect Preliminary',
                          'Core Post Retirement Adjustment 12MM Basic EPS Effect Preliminary',
                          'Core Post Retirement Adjustment Basic EPS Effect Preliminary',
                          'Core Post Retirement Adjustment Preliminary',
                          'Reversal - Restructruring/Acquisition Aftertax 12MM',
                          'Reversal - Restructuring/Acq Diluted EPS Effect 12MM',
                          'Reversal - Restructuring/Acq Basic EPS Effect 12MM',
                          'Settlement (Litigation/Insurance) AfterTax - 12mm',
                          'Settlement (Litigation/Insurance) Diluted EPS Effect 12MM',
                          'Settlement (Litigation/Insurance) Basic EPS Effect 12MM',
                          'S&P Core Earnings 12MM',
                          'S&P Core Earnings EPS Diluted 12MM',
                          'S&P Core Earnings EPS Diluted - Preliminary',
                          'S&P Core Earnings EPS Basic 12MM',
                          'S&P Core 12MM EPS - Basic - Preliminary',
                          'S&P Core Earnings EPS Basic - Preliminary',
                          'S&P Core Earnings 12MM - Preliminary',
                          'S&P Core Earnings 12MM EPS Diluted - Preliminary',
                          'S&P Core Earnings - Preliminary',
                          'Implied Option Expense - 12mm',
                          'Implied Option EPS Diluted 12MM',
                          'Implied Option 12MM EPS Diluted Preliminary',
                          'Implied Option EPS Diluted Preliminary',
                          'Implied Option EPS Basic 12MM',
                          'Implied Option 12MM EPS Basic Preliminary',
                          'Implied Option EPS Basic Preliminary',
                          'Implied Option Expense Preliminary']

quarterly_financial_data.drop(columns=quarterly_columns_drop, inplace=True)

# %%
rename_dict_quarterly = {"Level of Consolidation - Company Interim Descriptor": "Level of Consolidation",
                         "Assets - Other - Total": "Assets - Other",
                         "Account Payable/Creditors": "Accounts Payable/Creditors",
                         "Depreciation and Amortization - Total": "Depreciation and Amortization",
                         'Equity in Earnings (I/S) - Unconsolidated Subsidiaries': 'Equity in Earnings - Unconsolidated Subsidiaries',
                         "Impairment of Goodwill Diluted EPS Effect": "Impairments of Goodwill Diluted EPS Effect",
                         'Impairment of Goodwill Pretax': 'Impairments of Goodwill Pretax',
                         "Invested Capital - Total - Quarterly": "Invested Capital - Total",
                         "Short-Term Investments- Total": "Short-Term Investments - Total",
                         "Liabilities - Other": "Liabilities - Other - Total",
                         "Order backlog": "Order Backlog",
                         'Operating Income After Depreciation - Quarterly': 'Operating Income After Depreciation',
                         'Operating Income Before Depreciation - Quarterly': 'Operating Income Before Depreciation',
                         'Nonred Pfd Shares Outs (000) - Quarterly':  'Nonred Pfd Shares Outs (000)',
                         'Property, Plant and Equipment - Total (Gross) - Quarterly': 'Property, Plant and Equipment - Total (Gross)',
                         'Property Plant and Equipment - Total (Gross)': 'Property, Plant and Equipment - Total (Gross)',
                         'Restructuring Cost After-tax': 'Restructuring Costs After-tax',
                         'Restructuring Cost Diluted EPS Effect': 'Restructuring Costs Diluted EPS Effect',
                         'Restructuring Cost Basic EPS Effect': 'Restructuring Costs Basic EPS Effect',
                         'Restructuring Cost Pretax': 'Restructuring Costs Pretax',
                         'In Process R&D': 'In Process R&D Expense',
                         'Unbilled Receivables - Quarterly': "Unbilled Receivables",
                         'Unadjusted Retained Earnings': 'Retained Earnings - Unadjusted',
                         'Current Deferred Tax Asset': 'Deferred Tax Asset - Current',
                         "Current Deferred Tax Liability": "Deferred Tax Liability - Current",
                         "Deferred Taxes - Balance Sheet": "Deferred Taxes (Balance Sheet)",
                         "Contributions In Aid Of Construction": "Contributions in Aid of Construction",
                         "Debt (Other Long-Term)": "Other Long-term Debt",
                         "Other Long-term Debt": "Other Long-Term Debt",
                         "Interest and Related Expense- Total": "Interest and Related Expense - Total",
                         "Operating Expense- Total": "Operating Expense - Total",
                         "Operating Expense - Total": "Operating Expenses - Total"}

quarterly_financial_data = quarterly_financial_data.rename(columns=rename_dict_quarterly)

# %%
rename_dict_annual = {"Acquisition/Merger After-tax": "Acquisition/Merger After-Tax",
                         "Debt in Current Liabilities - Total": "Debt in Current Liabilities",
                         'Gain/Loss After-tax': 'Gain/Loss After-Tax',
                         "Inventories - Finished Goods": "Inventory - Finished Goods",
                         "Inventories - Other": "Inventory - Other",
                         'Inventories - Raw Materials': 'Inventory - Raw Materials',
                         'Inventories - Work in Process': 'Inventory - Work in Process',
                         "Noncontrolling Interest (Income Account)": "Noncontrolling Interest - Income Account",
                         'Nonoperating Income (Expense)': 'Non-Operating Income (Expense) - Total',
                         'Nonrecurring Income Taxes After-tax': 'Nonrecurring Income Taxes - After-tax',
                         "Nonrecurring Income Tax Diluted EPS Effect": "Nonrecurring Income Taxes Diluted EPS Effect",
                         'Nonrecurring Income Tax Basic EPS Effect': 'Nonrecurring Income Taxes Basic EPS Effect',
                         'Common Equity Total - Utility': 'Common Equity - Total - Utility',
                         "Other Long-term Debt": "Other Long-Term Debt",
                         "Net Income before Extraordinary Items and after Noncontrolling Interest": "Net Income before Extraordinary Items After Noncontrolling Interest",
                         "Selling, General and Administrative Expense": "Selling, General and Administrative Expenses"}

annual_financial_data = annual_financial_data.rename(columns=rename_dict_annual)

# %%
annual_financial_data_column_list = list(annual_financial_data.columns)
quarterly_financial_data_column_list = list(quarterly_financial_data.columns)

similar_columns = []
quarterly_columns_not_in_annual = []

for quarterly_column in quarterly_financial_data_column_list:
    if quarterly_column in annual_financial_data:
        similar_columns.append(quarterly_column)
    if quarterly_column not in annual_financial_data_column_list:
        quarterly_columns_not_in_annual.append(quarterly_column)


annual_columns_not_in_quarterly = []

for annual_column in annual_financial_data_column_list:
    if annual_column not in quarterly_financial_data_column_list:
        annual_columns_not_in_quarterly.append(annual_column)

# %%
similar_columns
similar_cols_to_remove = ['Industry Format', 
                          'Population Source',
                          'Data Format',
                          'ISO Currency Code',
                          'Accounting Changes - Cumulative Effect',
                          'Active/Inactive Status Marker',
                          'CIK Number']

similar_columns = [col for col in similar_columns if col not in similar_cols_to_remove]

# %%
quarterly_columns_extra = ['Fiscal Year', 'Fiscal Quarter', 'Fiscal Data Year and Quarter']

quarterly_columns = quarterly_columns_extra + similar_columns
quarterly_financial_data_no_extra_columns = quarterly_financial_data[quarterly_columns]

quarterly_financial_data_no_extra_columns = quarterly_financial_data_no_extra_columns.drop(columns={'Unnamed: 0', 'Unnamed: 0.1'})
quarterly_financial_data_no_extra_columns = quarterly_financial_data_no_extra_columns.rename(columns={'Date_x': 'Date'})

quarterly_financial_data_no_extra_columns
# Out:
#        Fiscal Year  Fiscal Quarter Fiscal Data Year and Quarter  \
# 0             2010               1                       2010Q1
# 1             2010               2                       2010Q2
# 2             2010               3                       2010Q3
# 3             2010               4                       2010Q4
# 4             2011               1                       2011Q1
# ...            ...             ...                          ...
# 32604         2023               4                       2023Q4
# 32605         2024               1                       2024Q1
# 32606         2024               2                       2024Q2
# 32607         2024               3                       2024Q3
# 32608         2024               4                       2024Q4
#
#        Global Company Key       Date Ticker Symbol          Company Name  \
# 0                    1117 2010-03-31          BKTI  BK TECHNOLOGIES CORP
# ...

# %%
annual_financial_data_columns = similar_columns + ['Data Year - Fiscal', 'Employees']

annual_financial_data_no_extra_columns = annual_financial_data[annual_financial_data_columns]
annual_financial_data_no_extra_columns = annual_financial_data_no_extra_columns.drop(columns={'Unnamed: 0', 'Unnamed: 0.1'})
annual_financial_data_no_extra_columns = annual_financial_data_no_extra_columns.rename(columns={'Date_x': 'Date'})

annual_financial_data_no_extra_columns
# Out:
#       Global Company Key       Date Ticker Symbol          Company Name  \
# 0                   1117 2010-12-31          BKTI  BK TECHNOLOGIES CORP
# 1                   1117 2011-12-31          BKTI  BK TECHNOLOGIES CORP
# 2                   1117 2012-12-31          BKTI  BK TECHNOLOGIES CORP
# 3                   1117 2013-12-31          BKTI  BK TECHNOLOGIES CORP
# 4                   1117 2014-12-31          BKTI  BK TECHNOLOGIES CORP
# ...                  ...        ...           ...                   ...
# 8144              338703 2020-12-31          SVRE     SAVERONE 2014 LTD
# 8145              338703 2021-12-31          SVRE     SAVERONE 2014 LTD
# 8146              338703 2022-12-31          SVRE     SAVERONE 2014 LTD
# 8147              338703 2023-12-31          SVRE     SAVERONE 2014 LTD
# 8148              338703 2024-12-31          SVRE     SAVERONE 2014 LTD
#
#       Accumulated Other Comprehensive Income (Loss)  \
# ...

# %%
quarterly_financial_data_no_extra_columns.to_excel("Quarterly Financial Data (No Extra Columns).xlsx")
annual_financial_data_no_extra_columns.to_excel("Annual Financial Data (No Extra Columns).xlsx")
